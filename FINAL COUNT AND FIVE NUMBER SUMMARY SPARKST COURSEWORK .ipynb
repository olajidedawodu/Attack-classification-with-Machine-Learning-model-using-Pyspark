# %%
pip install -q findspark
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import findspark


findspark.init('/home/bigdata/Documents/spark-3.0.0')

# %%
from pyspark import SparkConf, SparkContext, Row
from pyspark.streaming import StreamingContext
from pyspark.sql import SparkSession
from pyspark import*
from pyspark.sql.functions import col, when
import pandas as pd
import numpy as np
import sys
import os

# %%
#DataFrame operations inside your streaming program
def getSparkSessionInstance(sparkConf):
    
    if ("sparkSessionSingletonInstance" not in globals()):
        globals()["sparkSessionSingletonInstance"] = SparkSession.builder.config(conf=sparkConf).getOrCreate()
    return globals()["sparkSessionSingletonInstance"]

# %%
sc = SparkContext(appName= "UNSW")
ssc = StreamingContext(sc, 2)
ssc.checkpoint("checkpoint")

# %%
# Load data to create a DStream data

unsw_list = list()
# read the entire folder and add them into the Queue
entries = os.listdir('UNSW_data')
for entry in entries:
    print(entry)
    path="UNSW_data/" + entry
    unsw_list += [sc.textFile(path, 5)]
# Out:
# UNSW-NB15-8.csv
# UNSW-NB15-43.csv
# UNSW-NB15-39.csv
# UNSW-NB15-3.csv
# UNSW-NB15-1.csv
# UNSW-NB15-14.csv
# UNSW-NB15-17.csv
# UNSW-NB15-25.csv
# UNSW-NB15-27.csv
# UNSW-NB15-46.csv
# UNSW-NB15-4.csv
# UNSW-NB15-7.csv
# UNSW-NB15-29.csv
# UNSW-NB15-9.csv
# UNSW-NB15-38.csv
# UNSW-NB15-6.csv
# UNSW-NB15-49.csv
# UNSW-NB15-2.csv
# UNSW-NB15-5.csv
# UNSW-NB15-30.csv
# .~lock.UNSW-NB15-1.csv#
# UNSW-NB15-10.csv
# UNSW-NB15-18.csv
# UNSW-NB15-28.csv
# UNSW-NB15-35.csv
# UNSW-NB15-33.csv
# UNSW-NB15-22.csv
# UNSW-NB15-19.csv

# %%
unsw_list[2].take(3)
# Out:
# ['"59.166.0.8","48111","149.171.126.7","5190","tcp","FIN","1.6395999E-2","1036","2366","31","29","4","4","-","463527.72","1071968.9","12","14","255","255","2472443027","327436606","86","169","0","0","127.15737","3.16449","1421947909","1421947909","1.453818","1.209846","7.8599999E-4","6.5900001E-4","1.2700001E-4","0","0","0","0","0","7","9","3","1","1","1","1","","0"',
#  '"59.166.0.7","14767","149.171.126.5","80","tcp","FIN","1.1078809","1684","10168","31","29","3","4","http","11293.632","69350.414","14","18","255","255","1514550030","3665297448","120","565","1","3924","9043.1875","7918.4985","1421947908","1421947909","85.194153","65.13736","6.9000002E-4","0.000543","0.000147","0","0","1","0","0","2","1","2","1","1","1","1","","0"',
#  '"59.166.0.1","18659","149.171.126.7","14562","tcp","FIN","0.012538","2542","23122","31","29","7","14","-","1581751.5","1.4402297E+7","40","42","255","255","2716648099","572382181","64","551","0","0","18.4088","17.361631","1421947910","1421947910","0.312846","0.292146","6.9199997E-4","5.5599998E-4","0.000136","0","0","0","0","0","6","9","2","6","1","1","1","","0"']

# %%
rdd_stream = ssc.queueStream(unsw_list)

# %%
# Make the Queue Stream of data 
def AddNormalLabel(line1): 
            line =line1.replace('"','').split(",")
            if line[47]== '':
                line[47]= 'Normal'
            elif line[47] == 'Backdoor':
                line[47] ='Backdoors'
                   
            return line

# %%
words = rdd_stream.map(AddNormalLabel)

# %%
################ Solution (Transformation and Action) ################
datamap= words.filter(lambda x : x[47])
filtline = datamap.map(lambda x: x[47])
#streamdata =filtline.reduceByKey(lambda a, b: a+b)
count= filtline.countByValue()
count.pprint()

# %%
def process(time, rdd):
    print("========%s =========" % str(time))


    try:

        # Get the singleton instant of SparkSession
        spark = getSparkSessionInstance(rdd.context.getConf())
        

        #Convert RDD[String] to RDD[Row] to DataFrame
        rowRdd = rdd.map(lambda w: Row(word=w))     
        wordsDataFrame = spark.createDataFrame(rowRdd)
        
                          
              
        # Creates a temporary view using the DataFrame
        wordsDataFrame.createOrReplaceTempView("words")


        # Do word count on table using SQL and print it
        wordCountsDataFrame = spark.sql("select trim(word[47]) as attack_cat, count(*) as Total from words group by trim(word[47]) order by Total DESC")

        wordCountsDataFrame.show()
              
        worddf= spark.sql("select percentile_approx(word[11], 0.25) as sloss25, percentile_approx(word[11], 0.50) as sloss50, percentile_approx(word[11], 0.75) as sloss75, MAX(word[11]) as slossmax, avg(word[11]) as averagesloss, percentile_approx(word[22], 0.25) as tcprtt25, percentile_approx(word[22], 0.50) as tcprtt50, percentile_approx(word[22], 0.75) as tcprt75, MAX(word[22]) as tcprttmax , avg(word[22]) as tcprttavg from words")
      
        worddf.show()
        
    except:

         pass



words.foreachRDD(process)

# %%
ssc.start()
# Out:
# -------------------------------------------
# Time: 2020-05-19 01:43:34
# -------------------------------------------
# ('Normal', 35674)
# ('Fuzzers ', 325)
# ('Backdoors', 12)
# ('DoS', 107)
# ('Reconnaissance ', 254)
# ('Shellcode ', 25)
# ('Worms', 3)
# ('Generic', 13828)
# ('Exploits', 537)
# ('Analysis', 30)
#
# ========2020-05-19 01:43:34 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|35674|
# |       Generic|13828|
# |      Exploits|  537|
# |       Fuzzers|  325|
# |Reconnaissance|  254|
# |           DoS|  107|
# |      Analysis|   30|
# |     Shellcode|   25|
# |     Backdoors|   12|
# |         Worms|    3|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+-----------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|        tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+-----------------+
# |    0.0|    0.0|    3.0|       9|2.862210847524363|    57.0|    73.0|  132.0|      999|113.1706860911507|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+-----------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:36
# -------------------------------------------
# ('Normal', 42323)
# ('DoS', 584)
# ('Fuzzers ', 404)
# ('Backdoors', 10)
# ('Reconnaissance ', 298)
# ('Worms', 3)
# ('Shellcode ', 26)
# ('Generic', 5621)
# ('Exploits', 1441)
# ('Analysis', 85)
#
# ========2020-05-19 01:43:36 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|42323|
# |       Generic| 5621|
# |      Exploits| 1441|
# |           DoS|  584|
# |       Fuzzers|  404|
# |Reconnaissance|  298|
# |      Analysis|   85|
# |     Shellcode|   26|
# |     Backdoors|   10|
# |         Worms|    3|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    1.0|    7.0|       9|4.529520622108476|    59.0|    73.0|  132.0|      998|122.31918495914952|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:38
# -------------------------------------------
# ('Normal', 50795)
#
# ========2020-05-19 01:43:38 =========
# +----------+-----+
# |attack_cat|Total|
# +----------+-----+
# |    Normal|50795|
# +----------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    4.0|    7.0|       9|6.115227876759524|    62.0|    73.0|  120.0|       99|125.60376021261935|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:40
# -------------------------------------------
# ('Normal', 39651)
# ('DoS', 602)
# ('Fuzzers ', 607)
# ('Backdoors', 74)
# ('Reconnaissance ', 406)
# ('Shellcode ', 46)
# ('Worms', 4)
# ('Exploits', 1299)
# ('Analysis', 74)
# ('Generic', 8032)
#
# ========2020-05-19 01:43:40 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|39651|
# |       Generic| 8032|
# |      Exploits| 1299|
# |       Fuzzers|  607|
# |           DoS|  602|
# |Reconnaissance|  406|
# |     Backdoors|   74|
# |      Analysis|   74|
# |     Shellcode|   46|
# |         Worms|    4|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    0.0|    7.0|      94|4.521429274534895|    58.0|    73.0|  132.0|      999|122.12587853135152|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:42
# -------------------------------------------
# ('Normal', 49050)
# ('Fuzzers ', 242)
# ('DoS', 298)
# ('Backdoors', 31)
# ('Reconnaissance ', 235)
# ('Worms', 3)
# ('Shellcode ', 23)
# ('Exploits', 680)
# ('Generic', 207)
# ('Analysis', 26)
#
# ========2020-05-19 01:43:42 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|49050|
# |      Exploits|  680|
# |           DoS|  298|
# |       Fuzzers|  242|
# |Reconnaissance|  235|
# |       Generic|  207|
# |     Backdoors|   31|
# |      Analysis|   26|
# |     Shellcode|   23|
# |         Worms|    3|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    4.0|    7.0|      98|5.707786199429077|    63.0|    73.0|  120.0|      995|126.58993995471995|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:44
# -------------------------------------------
# ('Fuzzers ', 770)
# ('Normal', 37904)
# ('DoS', 167)
# ('Backdoors', 22)
# ('Reconnaissance ', 339)
# ('Shellcode ', 42)
# ('Worms', 6)
# ('Generic', 10621)
# ('Exploits', 850)
# ('Analysis', 74)
#
# ========2020-05-19 01:43:44 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|37904|
# |       Generic|10621|
# |      Exploits|  850|
# |       Fuzzers|  770|
# |Reconnaissance|  339|
# |           DoS|  167|
# |      Analysis|   74|
# |     Shellcode|   42|
# |     Backdoors|   22|
# |         Worms|    6|
# +--------------+-----+
#
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|      averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
# |    0.0|    0.0|    7.0|      97|4.1040259868097255|    57.0|    66.0|  132.0|      997|114.29542277783247|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:46
# -------------------------------------------
# ('Normal', 37754)
# ('Fuzzers ', 398)
# ('DoS', 122)
# ('Backdoors', 17)
# ('Reconnaissance ', 260)
# ('Shellcode ', 31)
# ('Worms', 2)
# ('Generic', 11537)
# ('Exploits', 646)
# ('Analysis', 28)
#
# ========2020-05-19 01:43:46 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|37754|
# |       Generic|11537|
# |      Exploits|  646|
# |       Fuzzers|  398|
# |Reconnaissance|  260|
# |           DoS|  122|
# |     Shellcode|   31|
# |      Analysis|   28|
# |     Backdoors|   17|
# |         Worms|    2|
# +--------------+-----+
#
# +-------+-------+-------+--------+----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|    averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+----------------+--------+--------+-------+---------+------------------+
# |    0.0|    0.0|    4.0|     934|3.49595432621321|    57.0|    73.0|  132.0|      990|114.69201693080028|
# +-------+-------+-------+--------+----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:48
# -------------------------------------------
# ('Normal', 42859)
# ('Fuzzers ', 910)
# ('Backdoors', 201)
# ('DoS', 1432)
# ('Reconnaissance ', 629)
# ('Shellcode ', 68)
# ('Worms', 8)
# ('Exploits', 2221)
# ('Generic', 2287)
# ('Analysis', 180)
#
# ========2020-05-19 01:43:48 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|42859|
# |       Generic| 2287|
# |      Exploits| 2221|
# |           DoS| 1432|
# |       Fuzzers|  910|
# |Reconnaissance|  629|
# |     Backdoors|  201|
# |      Analysis|  180|
# |     Shellcode|   68|
# |         Worms|    8|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    3.0|    7.0|      99|5.319027463333005|    61.0|    73.0|  130.0|      994|129.22687272369328|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:50
# -------------------------------------------
# ('Normal', 38414)
# ('Fuzzers ', 454)
# ('DoS', 168)
# ('Backdoors', 20)
# ('Reconnaissance ', 288)
# ('Shellcode ', 32)
# ('Worms', 3)
# ('Generic', 10574)
# ('Exploits', 812)
# ('Analysis', 30)
#
# ========2020-05-19 01:43:50 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|38414|
# |       Generic|10574|
# |      Exploits|  812|
# |       Fuzzers|  454|
# |Reconnaissance|  288|
# |           DoS|  168|
# |     Shellcode|   32|
# |      Analysis|   30|
# |     Backdoors|   20|
# |         Worms|    3|
# +--------------+-----+
#
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|      averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
# |    0.0|    0.0|    6.0|       9|3.6039767693670637|    57.0|    73.0|  132.0|      998|116.82201004035831|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:52
# -------------------------------------------
# ('Normal', 50795)
#
# ========2020-05-19 01:43:52 =========
# +----------+-----+
# |attack_cat|Total|
# +----------+-----+
# |    Normal|50795|
# +----------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    4.0|    7.0|       9|5.883374347868885|    62.0|    73.0|  120.0|      996|122.28048036224038|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:54
# -------------------------------------------
# ('Normal', 42781)
# ('Fuzzers ', 822)
# ('DoS', 175)
# ('Backdoors', 24)
# ('Reconnaissance ', 454)
# ('Shellcode ', 59)
# ('Worms', 7)
# ('Generic', 5313)
# ('Exploits', 1111)
# ('Analysis', 49)
#
# ========2020-05-19 01:43:54 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|42781|
# |       Generic| 5313|
# |      Exploits| 1111|
# |       Fuzzers|  822|
# |Reconnaissance|  454|
# |           DoS|  175|
# |     Shellcode|   59|
# |      Analysis|   49|
# |     Backdoors|   24|
# |         Worms|    7|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    2.0|    7.0|      97|5.192558322669554|    60.0|    73.0|  132.0|      998|125.75790924303573|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:56
# -------------------------------------------
# ('Normal', 36005)
# ('DoS', 1434)
# ('Fuzzers ', 583)
# ('Backdoors', 179)
# ('Reconnaissance ', 621)
# ('Shellcode ', 45)
# ('Worms', 8)
# ('Generic', 9719)
# ('Exploits', 2033)
# ('Analysis', 168)
#
# ========2020-05-19 01:43:56 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|36005|
# |       Generic| 9719|
# |      Exploits| 2033|
# |           DoS| 1434|
# |Reconnaissance|  621|
# |       Fuzzers|  583|
# |     Backdoors|  179|
# |      Analysis|  168|
# |     Shellcode|   45|
# |         Worms|    8|
# +--------------+-----+
#
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|      averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
# |    0.0|    0.0|    4.0|     934|3.4943793680480364|    57.0|    87.0|  132.0|      998|118.84144108672113|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:43:58
# -------------------------------------------
# ('Normal', 45824)
# ('Reconnaissance', 497)
# ('Fuzzers', 1649)
# ('DoS', 354)
# ('Backdoors', 188)
# ('Shellcode', 75)
# ('Reconnaissance ', 4)
# ('Worms', 7)
# ('Shellcode ', 3)
# ('Exploits', 1585)
# ...
#
# ========2020-05-19 01:43:58 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|45824|
# |       Fuzzers| 1649|
# |      Exploits| 1585|
# |Reconnaissance|  501|
# |       Generic|  438|
# |           DoS|  354|
# |     Backdoors|  188|
# |      Analysis|  171|
# |     Shellcode|   78|
# |         Worms|    7|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    3.0|    7.0|      99|6.103651934245496|    60.0|    73.0|  120.0|      995|135.14158873904913|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:00
# -------------------------------------------
# ('Normal', 39178)
# ('Fuzzers ', 723)
# ('DoS', 171)
# ('Backdoors', 20)
# ('Reconnaissance ', 336)
# ('Worms', 3)
# ('Shellcode ', 39)
# ('Generic', 9405)
# ('Exploits', 867)
# ('Analysis', 53)
#
# ========2020-05-19 01:44:00 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|39178|
# |       Generic| 9405|
# |      Exploits|  867|
# |       Fuzzers|  723|
# |Reconnaissance|  336|
# |           DoS|  171|
# |      Analysis|   53|
# |     Shellcode|   39|
# |     Backdoors|   20|
# |         Worms|    3|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    0.0|    7.0|       9|3.717590314007284|    57.0|    73.0|  132.0|      994|118.46136430751058|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:02
# -------------------------------------------
# ('Normal', 50795)
#
# ========2020-05-19 01:44:02 =========
# +----------+-----+
# |attack_cat|Total|
# +----------+-----+
# |    Normal|50795|
# +----------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    1.0|    6.0|    7.0|      94|7.011575942514027|    61.0|    66.0|  120.0|      999|128.45874593956097|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# -------------------------------------------
# Time: 2020-05-19 01:44:04
# -------------------------------------------
# ('Normal', 44109)
# ('Fuzzers ', 728)
# ('DoS', 838)
# ('Backdoors', 98)
# ('Reconnaissance ', 632)
# ('Worms', 6)
# ('Shellcode ', 51)
# ('Exploits', 1754)
# ('Generic', 2497)
# ('Analysis', 82)
#
# ========2020-05-19 01:44:04 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|44109|
# |       Generic| 2497|
# |      Exploits| 1754|
# |           DoS|  838|
# |       Fuzzers|  728|
# |Reconnaissance|  632|
# |     Backdoors|   98|
# |      Analysis|   82|
# |     Shellcode|   51|
# |         Worms|    6|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    3.0|    7.0|      94|5.528713456048823|    61.0|    73.0|  131.0|      998|129.59316861895857|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:06
# -------------------------------------------
# ('Normal', 50795)
#
# ========2020-05-19 01:44:06 =========
# +----------+-----+
# |attack_cat|Total|
# +----------+-----+
# |    Normal|50795|
# +----------+-----+
#
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|      averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
# |    0.0|    5.0|    7.0|       9|6.1349148538241955|    62.0|    73.0|  120.0|       99|126.79791318043114|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:08
# -------------------------------------------
# ('Normal', 41773)
# ('DoS', 1542)
# ('Fuzzers ', 714)
# ('Backdoors', 186)
# ('Reconnaissance ', 616)
# ('Shellcode ', 55)
# ('Worms', 10)
# ('Exploits', 2288)
# ('Generic', 3438)
# ('Analysis', 173)
#
# ========2020-05-19 01:44:08 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|41773|
# |       Generic| 3438|
# |      Exploits| 2288|
# |           DoS| 1542|
# |       Fuzzers|  714|
# |Reconnaissance|  616|
# |     Backdoors|  186|
# |      Analysis|  173|
# |     Shellcode|   55|
# |         Worms|   10|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    2.0|    7.0|      94|5.072113396987892|    60.0|    73.0|  132.0|      998|126.04466975095974|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:10
# -------------------------------------------
# ('Normal', 46784)
# ('Fuzzers ', 960)
# ('Backdoors', 30)
# ('DoS', 259)
# ('Reconnaissance ', 511)
# ('Shellcode ', 60)
# ('Worms', 3)
# ('Exploits', 1336)
# ('Generic', 817)
# ('Analysis', 35)
#
# ========2020-05-19 01:44:10 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|46784|
# |      Exploits| 1336|
# |       Fuzzers|  960|
# |       Generic|  817|
# |Reconnaissance|  511|
# |           DoS|  259|
# |     Shellcode|   60|
# |      Analysis|   35|
# |     Backdoors|   30|
# |         Worms|    3|
# +--------------+-----+
#
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+-----------------+
# |sloss25|sloss50|sloss75|slossmax|      averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|        tcprttavg|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+-----------------+
# |    0.0|    4.0|    7.0|      99|6.1344423663746435|    62.0|    73.0|  129.0|      999|133.0149424155921|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+-----------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:12
# -------------------------------------------
# ('Normal', 43174)
# ('Fuzzers', 1544)
# ('Backdoors', 295)
# ('DoS', 468)
# ('Reconnaissance', 453)
# ('Shellcode', 52)
# ('Worms', 8)
# ('Analysis', 277)
# ('Exploits', 1731)
# ('Generic', 2793)
#
# ========2020-05-19 01:44:12 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|43174|
# |       Generic| 2793|
# |      Exploits| 1731|
# |       Fuzzers| 1544|
# |           DoS|  468|
# |Reconnaissance|  453|
# |     Backdoors|  295|
# |      Analysis|  277|
# |     Shellcode|   52|
# |         Worms|    8|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+-----------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|        tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+-----------------+
# |    0.0|    3.0|    7.0|     934|5.493769071759031|    60.0|    73.0|  132.0|      999|131.7510778619943|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+-----------------+
#
# ========2020-05-19 01:44:14 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:16
# -------------------------------------------
# ('Normal', 43141)
# ('Fuzzers ', 888)
# ('DoS', 203)
# ('Backdoors', 29)
# ('Reconnaissance ', 436)
# ('Shellcode ', 55)
# ('Worms', 7)
# ('Generic', 4925)
# ('Exploits', 1101)
# ('Analysis', 10)
#
# ========2020-05-19 01:44:16 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|43141|
# |       Generic| 4925|
# |      Exploits| 1101|
# |       Fuzzers|  888|
# |Reconnaissance|  436|
# |           DoS|  203|
# |     Shellcode|   55|
# |     Backdoors|   29|
# |      Analysis|   10|
# |         Worms|    7|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    2.0|    7.0|      99|5.091505069396594|    60.0|    73.0|  132.0|      999|128.27959444827246|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:18
# -------------------------------------------
# ('Normal', 39800)
# ('Fuzzers ', 761)
# ('DoS', 164)
# ('Backdoors', 21)
# ('Reconnaissance ', 333)
# ('Shellcode ', 38)
# ('Worms', 5)
# ('Exploits', 851)
# ('Generic', 8792)
# ('Analysis', 30)
#
# ========2020-05-19 01:44:18 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|39800|
# |       Generic| 8792|
# |      Exploits|  851|
# |       Fuzzers|  761|
# |Reconnaissance|  333|
# |           DoS|  164|
# |     Shellcode|   38|
# |      Analysis|   30|
# |     Backdoors|   21|
# |         Worms|    5|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    0.0|    6.0|       9|3.932906782163599|    57.0|    73.0|  132.0|      994|122.09495029038291|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:20
# -------------------------------------------
# ('Normal', 42630)
# ('Fuzzers ', 468)
# ('DoS', 218)
# ('Backdoors', 26)
# ('Fuzzers', 430)
# ('Reconnaissance', 145)
# ('Shellcode', 18)
# ('Reconnaissance ', 251)
# ('Shellcode ', 33)
# ('Worms', 4)
# ...
#
# ========2020-05-19 01:44:20 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|42630|
# |       Generic| 5479|
# |      Exploits| 1053|
# |       Fuzzers|  898|
# |Reconnaissance|  396|
# |           DoS|  218|
# |     Shellcode|   51|
# |      Analysis|   40|
# |     Backdoors|   26|
# |         Worms|    4|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+-----------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|        tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+-----------------+
# |    0.0|    2.0|    7.0|      97|4.560271680283493|    59.0|    73.0|  132.0|      994|122.4197263510188|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+-----------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:22
# -------------------------------------------
# ('Normal', 50795)
#
# ========2020-05-19 01:44:22 =========
# +----------+-----+
# |attack_cat|Total|
# +----------+-----+
# |    Normal|50795|
# +----------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    6.0|    7.0|       9|6.204744561472586|    62.0|    73.0|  120.0|      991|126.42366374643173|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:24
# -------------------------------------------
# ('Normal', 50792)
# ('Reconnaissance ', 1)
# ('Exploits', 1)
# ('Generic', 1)
#
# ========2020-05-19 01:44:24 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|50792|
# |      Exploits|    1|
# |       Generic|    1|
# |Reconnaissance|    1|
# +--------------+-----+
#
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|     averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
# |    0.0|    5.0|    7.0|       9|6.144443350723496|    61.0|    73.0|  128.0|      991|129.24049611182204|
# +-------+-------+-------+--------+-----------------+--------+--------+-------+---------+------------------+
#
# -------------------------------------------
# Time: 2020-05-19 01:44:26
# -------------------------------------------
# ('Normal', 38810)
# ('DoS', 96)
# ('Fuzzers ', 440)
# ('Backdoors', 10)
# ('Reconnaissance ', 292)
# ('Shellcode ', 31)
# ('Worms', 2)
# ('Generic', 10388)
# ('Exploits', 677)
# ('Analysis', 49)
#
# ========2020-05-19 01:44:26 =========
# +--------------+-----+
# |    attack_cat|Total|
# +--------------+-----+
# |        Normal|38810|
# |       Generic|10388|
# |      Exploits|  677|
# |       Fuzzers|  440|
# |Reconnaissance|  292|
# |           DoS|   96|
# |      Analysis|   49|
# |     Shellcode|   31|
# |     Backdoors|   10|
# |         Worms|    2|
# +--------------+-----+
#
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
# |sloss25|sloss50|sloss75|slossmax|      averagesloss|tcprtt25|tcprtt50|tcprt75|tcprttmax|         tcprttavg|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
# |    0.0|    0.0|    5.0|      90|3.2694162811300327|    57.0|    73.0|  132.0|      998|117.26849099320799|
# +-------+-------+-------+--------+------------------+--------+--------+-------+---------+------------------+
#
# ========2020-05-19 01:44:28 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:30
# -------------------------------------------
#
# ========2020-05-19 01:44:30 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:32
# -------------------------------------------
#
# ========2020-05-19 01:44:32 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:34
# -------------------------------------------
#
# ========2020-05-19 01:44:34 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:36
# -------------------------------------------
#
# ========2020-05-19 01:44:36 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:38
# -------------------------------------------
#
# ========2020-05-19 01:44:38 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:40
# -------------------------------------------
#
# ========2020-05-19 01:44:40 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:42
# -------------------------------------------
#
# ========2020-05-19 01:44:42 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:44
# -------------------------------------------
#
# ========2020-05-19 01:44:44 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:46
# -------------------------------------------
#
# ========2020-05-19 01:44:46 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:48
# -------------------------------------------
#
# ========2020-05-19 01:44:48 =========
# -------------------------------------------
# Time: 2020-05-19 01:44:50
# -------------------------------------------
#
# ========2020-05-19 01:44:50 =========

# %%
ssc.stop(stopSparkContext=True, stopGraceFully=True)
